# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso
sns.set()
import plotly.express as px

# %%
data1 = pd.read_csv('C:\\Users\\Admin/cap_clean2.csv')

# %%
data = pd.read_csv('C:\\Users\\Admin/cap_clean1.csv')

# %%
data1.head()
# Out:
#    Population   Age  Gender  Race  Manner_of_death  Armed  Mental_illness  \
# 0      196620   NaN       2    -1               -1     -1               2
# 1      196620   NaN       2    -1               -1     -1               2
# 2      101764  50.0       2     1                1     19               1
# 3      101764  23.0       2     1                1     19               1
# 4      101764  48.0       2     1                1      8               1
#
#    Flee        Date
# 0     2         NaN
# 1     2         NaN
# 2     1  2005-04-18
# 3     1  2007-10-14
# 4     1  2014-06-09

# %%
data.head()
# Out:
#      State         City  Population   Age Gender   Race Manner_of_death Armed  \
# 0  alabama  huntsville4      196620   NaN    NaN    NaN             NaN   NaN
# 1  alabama  huntsville4      196620   NaN    NaN    NaN             NaN   NaN
# 2  alabama   tuscaloosa      101764  50.0   male  black            shot   NaN
# 3  alabama   tuscaloosa      101764  23.0   male  black            shot   NaN
# 4  alabama   tuscaloosa      101764  48.0   male  black            shot   gun
#
#   Mental_illness   Flee        Date
# 0            NaN    NaN         NaN
# 1            NaN    NaN         NaN
# 2          False  False  2005-04-18
# 3          False  False  2007-10-14
# 4          False  False  2014-06-09

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data1.corr(), annot = True, cmap = 'Blues_r')
plt.ioff()

# %%
sns.boxplot(x='Race',y='Flee',data=data)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Flee'>

# %%
sns.boxplot(x='Gender',y='Flee',data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Flee'>

# %%
sns.countplot(x='Manner_of_death',data=data)
# Out:
# <AxesSubplot:xlabel='Manner_of_death', ylabel='count'>

# %%
sns.countplot(x='Age',data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Flee',data=data)
# Out:
# <AxesSubplot:xlabel='Flee', ylabel='count'>

# %%
sns.catplot(x="Race",y="Flee",hue="Gender",data=data,dodge=True)

# %%
data.Flee.value_counts().plot(kind='pie',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Flee'>

# %%
data.Age.value_counts().plot(kind='pie',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.factorplot('Manner_of_death','Flee',hue='Gender',data=data1)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set(rc={'figure.figsize':(15.7,8.17)})
sns.scatterplot(data=data, x='Race', y= "Flee",  hue="Gender")
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Flee'>

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=data["Age"],hue=data["Armed"],palette="ch:s=.25,rot=-.25")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot = True, cmap = 'Blues_r')
plt.ioff()

# %%
sns.relplot(x="Population",y="Flee", data=data)

# %%
sns.relplot(x="Race",y="Flee", data=data)

# %%
import matplotlib.pyplot as plt
import pylab as pl

# %%
#Fatality/100k pop w.r.t gender
pl.figure(figsize =(10,5))
plt.xlabel('Fatality/100k pop', fontsize=12)
plt.ylabel('Gender', fontsize=12)
plt.title('Fatality/100k Population by Gender', fontsize=15)
sns.boxplot(x="Manner_of_death", y="Flee", data=data, whis="range", palette="vlag")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   artist_dict = ax.boxplot(box_data,
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   artist_dict = ax.boxplot(box_data,
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   artist_dict = ax.boxplot(box_data,
# ...

# %%
sns.boxplot(x='Age',y='Flee',data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Flee'>

# %%
#Fatality/100k pop w.r.t gender
pl.figure(figsize =(10,5))
plt.xlabel('Fatality/100k pop', fontsize=12)
plt.ylabel('Flee', fontsize=12)
plt.title('Fatality/100k Population by Gender', fontsize=15)
sns.boxplot(x="Manner_of_death", y="Flee", data=data, whis="range", palette="vlag")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   artist_dict = ax.boxplot(box_data,
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   artist_dict = ax.boxplot(box_data,
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:441: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   artist_dict = ax.boxplot(box_data,
# ...
